# %% [markdown]
# # I. BANK CHURN PREDICTION | Data Preparation & Visualization Insight
# [Datasets Source](https://www.kaggle.com/shrutimechlearn/churn-modelling)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## Importing Dataset

# %%
data = pd.read_csv("Churn_Modelling.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# #### Checking NaN values on datasets

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# There's no NaN value in datasets

# %% [markdown]
# #### Drop Several Features
#
# Asumsi data yang diabaikan karena tidak berpengaruh ke model :
# - `RowNumber`
# - `CustomerId`
# - `Surname`

# %%
datadrop = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)
datadrop
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
datadrop.describe().T
# Out:
#                    count           mean           std     min       25%  \
# CreditScore      10000.0     650.528800     96.653299  350.00    584.00
# Age              10000.0      38.921800     10.487806   18.00     32.00
# Tenure           10000.0       5.012800      2.892174    0.00      3.00
# Balance          10000.0   76485.889288  62397.405202    0.00      0.00
# NumOfProducts    10000.0       1.530200      0.581654    1.00      1.00
# HasCrCard        10000.0       0.705500      0.455840    0.00      0.00
# IsActiveMember   10000.0       0.515100      0.499797    0.00      0.00
# EstimatedSalary  10000.0  100090.239881  57510.492818   11.58  51002.11
# Exited           10000.0       0.203700      0.402769    0.00      0.00
#
#                         50%          75%        max
# CreditScore         652.000     718.0000     850.00
# Age                  37.000      44.0000      92.00
# Tenure                5.000       7.0000      10.00
# Balance           97198.540  127644.2400  250898.09
# NumOfProducts         1.000       2.0000       4.00
# HasCrCard             1.000       1.0000       1.00
# IsActiveMember        1.000       1.0000       1.00
# EstimatedSalary  100193.915  149388.2475  199992.48
# Exited                0.000       0.0000       1.00

# %% [markdown]
# <hr>
#
# ## Data Visualization

# %%
dtEx = datadrop[datadrop["Exited"] == 1]
dtRet = datadrop[datadrop["Exited"] == 0]

# %%
val = datadrop.loc[:,"Exited"].value_counts()
ind = datadrop["Exited"].value_counts().sort_index().index

plt.figure(figsize=[5,5])
plt.title("BANK CUSTOMER COMPARISON", size= 12)
sb.set(style="darkgrid")
mark = sb.barplot(x= ind, y= val, data= datadrop, ci=None)
for p in mark.patches:
             mark.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha="center", va="center", fontsize=11, color="black", rotation=0, xytext=(0, 5),
                 textcoords="offset points")
plt.xlabel("Exited")
plt.ylabel("Amount")
        
plt.show()

# %% [markdown]
# #### COMPARING CATEGORICAL DATA

# %%
column = ["Geography", "Gender", "NumOfProducts", "HasCrCard", "IsActiveMember"]

sb.set(style = "darkgrid")
fig = plt.figure(figsize = (30,15))

for i in range(len(column)):    
    val = datadrop.loc[:,column[i]].value_counts()
    ind = datadrop[column[i]].value_counts().sort_index().index
    
    ax1 = fig.add_subplot(2, 5, i+1)
    ax1.set_title(column[i])

    ax2 = fig.add_subplot(2, 5, 6+i)
    ax2.set_title("Comparison Exited (1) & Retained (0)")

    mark1 = sb.barplot(x = ind, y = val, ax= ax1 )
    for p in mark1.patches:
                 mark1.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha="center", va="center", fontsize=11, color="black", rotation=0, xytext=(0, 5),
                     textcoords="offset points")
    mark2 = sb.countplot(x = "Exited", hue = column[i], data = datadrop, ax = ax2)
    for p in mark2.patches:
                 mark2.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha="center", va="center", fontsize=11, color="black", rotation=0, xytext=(0, 5),
                     textcoords="offset points")

# %%
col = ["CreditScore", "Age", "Tenure", "Balance", "EstimatedSalary"]
sb.set(style = "darkgrid")
fig = plt.figure(figsize = (20,15))

for i in range(len(col)):
    a = fig.add_subplot(3, 2, i+1)
    a.set_title(col[i])
    datadrop[col[i]][datadrop["Exited"] == 0].hist(bins = 20, alpha = 0.5)
    datadrop[col[i]][datadrop["Exited"] == 1].hist(bins = 20, alpha = 0.5)

# %% [markdown]
# #### BOXPLOTTING NUMERICAL DATA

# %%
col = ["CreditScore", "Age", "Tenure", "Balance", "EstimatedSalary"]

sb.set(style = "darkgrid")
fig = plt.figure(figsize = (25,8))

for i in range(len(column)):
    plt.subplot(1, 5, i+1)
    datadrop.boxplot(column=[col[i]])

# %% [markdown]
# __Checking Outliers__ <br>
# Cek ke CreditScore dan Age

# %%
def cek_outlier(df, col_name):
    q1 = df[col_name].quantile(0.25)
    q3 = df[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    low  = q1-1.5*iqr
    high = q3+1.5*iqr
    print(f"Batas bawah {col_name} : {low}, dan batas atas : {high}")
cek = ["CreditScore", "Age"]

for i in cek:
    cek_outlier(datadrop, i)
# Out:
# Batas bawah CreditScore : 383.0, dan batas atas : 919.0
# Batas bawah Age : 14.0, dan batas atas : 62.0

# %% [markdown]
# Outliers tidak disisihkan, tapi akan ditampilkan sebagai peringatan dalam UI

# %% [markdown]
# <hr>
#
# ## Creating Dummy Variable for Categorical Data

# %%
dtGeo = pd.get_dummies(datadrop["Geography"])
dtGeo
# Out:
#       France  Germany  Spain
# 0          1        0      0
# 1          0        0      1
# 2          1        0      0
# 3          1        0      0
# 4          0        0      1
# ...      ...      ...    ...
# 9995       1        0      0
# 9996       1        0      0
# 9997       1        0      0
# 9998       0        1      0
# 9999       1        0      0
#
# [10000 rows x 3 columns]

# %%
dtGender = pd.get_dummies(datadrop["Gender"])
dtGender
# Out:
#       Female  Male
# 0          1     0
# 1          1     0
# 2          1     0
# 3          1     0
# 4          1     0
# ...      ...   ...
# 9995       0     1
# 9996       0     1
# 9997       1     0
# 9998       0     1
# 9999       1     0
#
# [10000 rows x 2 columns]

# %%
dtChurn = pd.concat([dtGeo, dtGender, datadrop], axis=1)
dtChurn.drop(["Geography", "Gender"], axis=1, inplace= True)
dtChurn
# Out:
#       France  Germany  Spain  Female  Male  CreditScore  Age  Tenure  \
# 0          1        0      0       1     0          619   42       2
# 1          0        0      1       1     0          608   41       1
# 2          1        0      0       1     0          502   42       8
# 3          1        0      0       1     0          699   39       1
# 4          0        0      1       1     0          850   43       2
# ...      ...      ...    ...     ...   ...          ...  ...     ...
# 9995       1        0      0       0     1          771   39       5
# 9996       1        0      0       0     1          516   35      10
# 9997       1        0      0       1     0          709   36       7
# 9998       0        1      0       0     1          772   42       3
# 9999       1        0      0       1     0          792   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0          0.00              1          1               1        101348.88
# 1      83807.86              1          0               1        112542.58
# 2     159660.80              3          1               0        113931.57
# 3          0.00              2          0               0         93826.63
# 4     125510.82              1          1               1         79084.10
# ...         ...            ...        ...             ...              ...
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 14 columns]

# %%
plt.figure(figsize= (20,12))
sb.heatmap(dtChurn.corr(method= "spearman"), annot= True)

# %%
dtChurn.corr(method= "spearman")["Exited"].sort_values()
# Out:
# IsActiveMember    -0.156128
# NumOfProducts     -0.125282
# Male              -0.106512
# France            -0.104955
# Spain             -0.052667
# CreditScore       -0.023289
# Tenure            -0.013978
# HasCrCard         -0.007138
# EstimatedSalary    0.012081
# Female             0.106512
# Balance            0.111110
# Germany            0.173488
# Age                0.323968
# Exited             1.000000
# Name: Exited, dtype: float64

# %% [markdown]
# Features yang berpengaruh besar :
# - Age (32.4%)
# - Germany[Geography] (17.3%)
# - IsActiveMember (15.6%)
# - NumofProducts (12.5%)
# - Male/Female[Gender] (10.7%)

# %%
dtChurn.to_csv("CM_Dummy.csv", index=False)
